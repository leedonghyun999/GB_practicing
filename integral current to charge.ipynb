# %%
# made by Gibeom LEE, HI LAB
# 전류 데이터를 적분하여 전하로 만들어줍니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import cumulative_trapezoid
import os

# %%
# fp는 업로드 된 파일, lp는 컴퓨터 내 파일. r주소
#file_path = "data/0M teng 2.csv"
local_path = r"C:\Users\GC\Desktop\학부연구생\3. 연구\1. Octopus patch\1. Data\1. 논문 데이터\2025.03.18 Demonstration 확대\visual studio c-OSIAs patch.csv"
# = r"여기를 바꾸세요"


# file path 불러오기
#df = pd.read_csv(file_path, header=None, skiprows=30)
# local path 불러오기
df = pd.read_csv(local_path, header=None)
# 데이터 로드 (처음 30행 스킵)
df.columns = ["Time", "Current"]

# 데이터 형식 변환...글자 -> NaN
df["Time"] = pd.to_numeric(df["Time"], errors='coerce')
df["Current"] = pd.to_numeric(df["Current"], errors='coerce')

#    *(10) = 10 μA/V 기준  %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 
df["Current"] = df["Current"]/(40000000)

print(df.iloc[:, 1].max(skipna=True))
print(df.iloc[:, 1].min(skipna=True))

plt.figure(figsize=(10, 5))
plt.plot(df.iloc[:, 0], df.iloc[:, 1], label="AC current", color='b')
plt.xlabel("Time (s)")
plt.ylabel("Current (A)")
plt.title("Original current - L6")
#plt.ylim(-0.3,4.5)
plt.grid(True)
plt.show()
# Out:
# 6.2129e-07
# -2.9375e-08

# %%
# 2. 특정 범위 선택      ########################## MUST BE MODIFIED MANUALLY
time_range = (0.25,0.5) #unit = sec    ###############여기서 시간 조절
df_filtered = df[(df.iloc[:, 0] >= time_range[0]) & (df.iloc[:, 0] <= time_range[1])]

# 3. 양수 및 음수 전류값 분리
p_value = df_filtered[df_filtered.iloc[:, 1] > 0]
n_value = df_filtered[df_filtered.iloc[:, 1] < 0]

# 4. 적분을 위한 시간과 전류값 배열 생성
p_time = p_value.iloc[:, 0].values
p_current = p_value.iloc[:, 1].values

n_time = n_value.iloc[:, 0].values
n_current = n_value.iloc[:, 1].values

# 5. 양수/음수 적분 (전하 계산)
p_charge = cumulative_trapezoid(p_current, p_time, initial=0)[-1] if len(p_time) > 1 else 0
n_charge = cumulative_trapezoid(n_current, n_time, initial=0)[-1] if len(n_time) > 1 else 0

print(f"양수 전하 값: {p_charge:.4f} C")
print(f"음수 전하 값: {n_charge:.4f} C")

plt.figure(figsize=(10, 5))
plt.plot(df_filtered.iloc[:, 0], df_filtered.iloc[:, 1], label="cut Current", color='g')
plt.xlabel("Time (s)")
plt.ylabel("Current (A)") ### 단위 고려 중요
plt.title("Cut current")
#plt.legend()
plt.grid(True)
plt.show()
# Out:
# 양수 전하 값: 0.0000 C
# 음수 전하 값: -0.0000 C

# %%
# 6. 중첩 적분 수행 (누적 전류)
cumulative_charge = cumulative_trapezoid(df_filtered.iloc[:, 1], df_filtered.iloc[:, 0], initial=0)

# 7. 중첩 적분 결과 플로팅
plt.figure(figsize=(10, 5))
plt.plot(df_filtered.iloc[:, 0], cumulative_charge, label="Cumulative Charge", color='r')
plt.xlabel("Time (s)")
plt.ylabel("Collected Charge (C)") ####단위 고려 중요요
plt.title("Collected charge (integrated currents)")
#plt.legend()
plt.grid(True)
plt.show()

# %%
# 기존 local_path에서 폴더 경로 및 원래 파일명 추출
folder_path = os.path.dirname(local_path)
original_filename = os.path.basename(local_path)  # 원래 파일명 가져오기
filtered_file_name = f"integrated_{original_filename}"  # "minimized_" 추가
filtered_file_path = os.path.join(folder_path, filtered_file_name)

# CSV 파일 저장
df_filtered.to_csv(filtered_file_path, index=False)
print(f"Filtered data saved at: {filtered_file_path}")
# Out:
# Filtered data saved at: C:\Users\GC\Desktop\학부연구생\3. 연구\1. Octopus patch\1. Data\1. 논문 데이터\2025.03.18 Demonstration 확대\integrated_visual studio c-OSIAs patch.csv
